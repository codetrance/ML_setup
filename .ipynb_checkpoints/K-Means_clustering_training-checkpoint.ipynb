# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=500,n_features=3,centers=6,cluster_std=1.8,
                 random_state=101)

# %%
data[0].shape
# Out:
# (500, 3)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
data[1]
# Out:
# array([2, 1, 2, 5, 1, 3, 4, 5, 1, 1, 5, 5, 1, 4, 0, 1, 2, 3, 2, 2, 3, 0,
#        1, 5, 0, 0, 4, 3, 5, 4, 3, 4, 3, 2, 4, 1, 4, 1, 5, 0, 2, 1, 4, 4,
#        1, 1, 3, 3, 3, 5, 5, 3, 1, 0, 0, 2, 4, 3, 2, 2, 5, 0, 5, 0, 4, 0,
#        2, 1, 0, 4, 0, 1, 3, 2, 4, 4, 5, 1, 3, 4, 0, 4, 0, 0, 3, 5, 2, 5,
#        3, 3, 3, 0, 4, 3, 3, 1, 2, 1, 1, 4, 4, 4, 1, 2, 0, 2, 0, 2, 2, 0,
#        4, 5, 3, 3, 5, 0, 0, 4, 3, 4, 0, 2, 3, 1, 0, 2, 3, 4, 3, 5, 3, 0,
#        4, 5, 4, 1, 1, 3, 3, 4, 2, 5, 4, 5, 0, 1, 3, 2, 4, 3, 2, 0, 3, 5,
#        1, 2, 1, 1, 3, 5, 5, 4, 5, 4, 0, 3, 4, 5, 2, 2, 4, 2, 0, 0, 1, 5,
#        3, 1, 0, 3, 2, 2, 2, 4, 0, 5, 2, 2, 0, 1, 3, 5, 0, 3, 4, 5, 3, 3,
#        3, 1, 0, 2, 2, 4, 0, 0, 1, 0, 0, 0, 2, 2, 4, 1, 2, 0, 5, 5, 1, 3,
#        4, 3, 4, 5, 2, 5, 4, 2, 5, 1, 1, 5, 1, 0, 0, 0, 0, 3, 5, 5, 1, 3,
#        1, 2, 0, 0, 5, 3, 5, 5, 1, 2, 0, 5, 3, 4, 2, 0, 2, 2, 4, 2, 3, 5,
#        5, 5, 0, 3, 0, 2, 0, 2, 3, 3, 1, 4, 3, 2, 5, 5, 4, 1, 4, 2, 4, 1,
#        4, 2, 0, 1, 5, 5, 1, 1, 2, 5, 3, 1, 1, 5, 0, 4, 1, 5, 2, 5, 0, 4,
#        3, 3, 1, 3, 0, 2, 1, 1, 0, 5, 3, 5, 3, 2, 2, 0, 3, 0, 5, 5, 1, 3,
#        2, 4, 4, 4, 4, 2, 3, 3, 2, 4, 5, 2, 5, 2, 1, 0, 1, 5, 1, 2, 3, 2,
#        5, 1, 1, 4, 2, 4, 2, 1, 0, 5, 1, 4, 3, 4, 4, 5, 1, 0, 2, 3, 3, 2,
#        0, 2, 0, 3, 4, 0, 4, 3, 0, 3, 3, 0, 3, 1, 0, 1, 1, 2, 5, 4, 0, 2,
#        1, 4, 0, 1, 4, 0, 5, 5, 1, 3, 0, 4, 5, 3, 5, 5, 5, 4, 3, 0, 5, 4,
#        0, 5, 1, 1, 4, 5, 2, 1, 2, 5, 5, 2, 1, 0, 0, 1, 4, 3, 5, 0, 2, 1,
#        2, 1, 0, 1, 1, 3, 1, 1, 4, 0, 4, 5, 2, 4, 1, 3, 5, 0, 2, 5, 4, 0,
#        5, 1, 4, 4, 2, 3, 2, 3, 5, 4, 3, 3, 5, 1, 2, 4, 2, 1, 1, 2, 4, 5,
#        1, 4, 4, 2, 4, 2, 0, 0, 3, 0, 4, 3, 4, 0, 5, 3])

# %%
from sklearn.cluster import KMeans

# %%
kmean = KMeans(n_clusters=4)

# %%
kmean.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmean.cluster_centers_
# Out:
# array([[-6.22723008,  1.18600162, -2.61606148],
#        [-5.38542369, -8.52410175,  2.23396651],
#        [ 0.68909749,  1.32231278, -9.30800279],
#        [-5.61611565,  5.71273321,  6.93020529]])

# %%
kmean.labels_
# Out:
# array([3, 3, 3, 1, 3, 0, 3, 1, 3, 3, 1, 0, 3, 3, 2, 3, 3, 0, 3, 3, 0, 2,
#        0, 1, 2, 2, 3, 0, 1, 3, 0, 3, 0, 3, 3, 3, 3, 3, 1, 2, 3, 3, 3, 3,
#        3, 3, 0, 0, 0, 1, 1, 0, 3, 2, 2, 3, 3, 0, 3, 3, 1, 2, 1, 2, 3, 2,
#        3, 3, 2, 3, 2, 3, 0, 3, 3, 3, 1, 3, 0, 3, 2, 3, 2, 2, 0, 1, 3, 1,
#        0, 0, 1, 2, 3, 0, 0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 3, 3, 2,
#        3, 1, 0, 0, 1, 2, 2, 3, 0, 3, 2, 3, 0, 3, 2, 3, 0, 3, 0, 1, 0, 2,
#        3, 1, 3, 3, 3, 0, 2, 3, 3, 1, 3, 1, 2, 3, 0, 3, 3, 0, 3, 2, 0, 1,
#        3, 3, 3, 3, 0, 1, 1, 3, 1, 3, 2, 0, 3, 1, 3, 3, 3, 3, 2, 2, 3, 1,
#        0, 3, 2, 0, 3, 3, 3, 3, 2, 1, 3, 3, 2, 3, 0, 1, 2, 0, 3, 1, 0, 0,
#        2, 3, 2, 3, 3, 3, 2, 2, 3, 2, 2, 2, 3, 3, 3, 3, 3, 2, 1, 1, 3, 0,
#        3, 0, 3, 1, 3, 1, 3, 3, 1, 3, 3, 1, 3, 2, 2, 2, 2, 0, 1, 1, 3, 0,
#        3, 3, 2, 2, 1, 0, 1, 1, 3, 3, 2, 1, 0, 3, 3, 2, 3, 3, 3, 3, 0, 1,
#        1, 1, 2, 0, 2, 3, 2, 3, 0, 0, 3, 3, 0, 3, 1, 1, 3, 3, 3, 3, 3, 3,
#        3, 3, 2, 3, 1, 1, 3, 3, 3, 1, 0, 3, 3, 1, 2, 3, 3, 1, 3, 1, 2, 3,
#        0, 0, 3, 0, 2, 3, 3, 3, 2, 1, 0, 1, 0, 3, 3, 2, 0, 2, 1, 1, 3, 0,
#        3, 3, 3, 3, 3, 3, 0, 0, 3, 3, 1, 3, 1, 3, 3, 2, 3, 1, 3, 3, 0, 3,
#        1, 3, 0, 3, 3, 3, 3, 3, 2, 1, 3, 3, 0, 3, 3, 1, 3, 2, 3, 0, 0, 3,
#        2, 3, 2, 0, 3, 2, 3, 0, 2, 0, 0, 2, 0, 3, 2, 3, 3, 3, 1, 3, 2, 3,
#        3, 3, 2, 3, 3, 2, 1, 1, 3, 0, 2, 3, 1, 0, 1, 1, 1, 3, 0, 2, 1, 3,
#        2, 1, 3, 3, 3, 1, 3, 3, 3, 1, 1, 3, 3, 2, 2, 3, 3, 0, 1, 2, 3, 3,
#        3, 3, 2, 3, 3, 0, 3, 3, 3, 2, 3, 1, 3, 3, 3, 0, 1, 2, 3, 1, 3, 2,
#        1, 3, 3, 3, 3, 0, 3, 0, 1, 3, 0, 0, 1, 3, 3, 3, 3, 3, 3, 3, 3, 1,
#        3, 3, 3, 3, 3, 3, 2, 2, 0, 2, 3, 0, 3, 2, 1, 0], dtype=int32)

# %%
fig,(ax1,ax2)=plt.subplots(1,2,sharey=True,figsize=(10,6))

ax1.set_title(' K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmean.labels_,cmap='rainbow')

ax2.set_title(' Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
